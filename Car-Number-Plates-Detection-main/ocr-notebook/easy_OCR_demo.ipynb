# %%
# Install EasyOCR
# !pip install easyocr
# Out:
# Requirement already satisfied: easyocr in c:\projects\final\car-number-plates-detection-main\venv\lib\site-packages (1.7.1)
# Requirement already satisfied: torch in c:\projects\final\car-number-plates-detection-main\venv\lib\site-packages (from easyocr) (2.2.0)
# Requirement already satisfied: torchvision>=0.5 in c:\projects\final\car-number-plates-detection-main\venv\lib\site-packages (from easyocr) (0.17.0)
# INFO: pip is looking at multiple versions of easyocr to determine which version is compatible with other requirements. This could take a while.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D636DD650>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/opencv-python-headless/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D63DF45D0>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/opencv-python-headless/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D63DF7950>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/opencv-python-headless/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D63DF7F50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/opencv-python-headless/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D63DF8790>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/opencv-python-headless/
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D63DF7C50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/easyocr/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D63DF5510>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/easyocr/
# WARNING: Retrying (Retry(total=2, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D63DDDB50>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/easyocr/
# WARNING: Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D63DE6450>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/easyocr/
# WARNING: Retrying (Retry(total=0, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x0000027D63DE7710>: Failed to establish a new connection: [Errno 11001] getaddrinfo failed')': /simple/easyocr/
# ERROR: Could not find a version that satisfies the requirement opencv-python-headless (from easyocr) (from versions: none)
# ERROR: No matching distribution found for opencv-python-headless

# %%
# Import necessary libraries
import cv2
import easyocr
from IPython.display import Image
import matplotlib.pyplot as plt

# %%
# Initialize EasyOCR reader
reader = easyocr.Reader(['en'])
# Out:
# Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.

# %%
# Path to your image
image_path = "C:\Projects\Final\Car-Number-Plates-Detection-main\plates\KAX 003S.jpg"

# %%
# Display the image
Image(image_path)

# %%
# Read text from the image
output = reader.readtext(image_path)

# %%
# Extract coordinates
cord = output[-1][0]

# Print the output and coordinates
print("Text detected:", output)
print("Coordinates:", cord)
# Out:
# Text detected: [([[36, 8], [607, 8], [607, 140], [36, 140]], 'KAX003S', 0.6679911210603895)]
# Coordinates: [[36, 8], [607, 8], [607, 140], [36, 140]]

# %%
# Extract bounding box coordinates
x_min, y_min = [int(min(idx)) for idx in zip(*cord)]
x_max, y_max = [int(max(idx)) for idx in zip(*cord)]

# %%
# Draw bounding box on the image
image = cv2.imread(image_path)
cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 0, 255), 2)
# Out:
# array([[[28, 27, 29],
#         [29, 28, 30],
#         [30, 29, 31],
#         ...,
#         [14, 12, 12],
#         [14, 12, 12],
#         [11, 11, 11]],
#
#        [[29, 28, 30],
#         [29, 28, 30],
#         [29, 28, 30],
#         ...,
#         [15, 13, 13],
#         [14, 12, 12],
#         [11, 11, 11]],
#
#        [[29, 28, 30],
#         [29, 28, 30],
#         [29, 28, 30],
#         ...,
#         [16, 14, 14],
#         [15, 13, 13],
#         [11, 11, 11]],
#
#        ...,
#
#        [[75, 42, 27],
#         [74, 41, 26],
#         [74, 41, 26],
#         ...,
#         [53, 30, 22],
#         [53, 30, 22],
#         [41, 28, 26]],
#
#        [[68, 39, 25],
#         [67, 38, 24],
#         [67, 38, 24],
#         ...,
#         [44, 25, 17],
#         [44, 25, 17],
#         [35, 26, 23]],
#
#        [[64, 41, 33],
#         [64, 41, 33],
#         [64, 41, 33],
#         ...,
#         [46, 33, 25],
#         [46, 33, 25],
#         [27, 20, 17]]], dtype=uint8)

# %%
# Display the image with bounding box
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
